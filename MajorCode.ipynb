# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthishreya/first-project-/blob/main/MajorCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
  import pandas as pd
  import numpy as np
  import re
  import nltk#Natural Language ToolKit -nltk
  from nltk.corpus import stopwords
  from nltk import ngrams
  from nltk import word_tokenize
  import string
  from sklearn import metrics
  from nltk.stem import PorterStemmer
  nltk.download('punkt')  # Ensure punkt is downloaded
  nltk.download('stopwords')  # Ensure stopwords are downloaded
  from nltk.corpus import stopwords
  from nltk.tokenize import word_tokenize
  nltk.download('punkt_tab')# used for tokenization
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df = pd.read_csv("/content/drive/MyDrive/ISEAR_dataset.csv",header=None)

# %%
df.head(5)
# Out:
#            0                                                  1    2
# 0  sentiment                                            content  NaN
# 1        joy  On days when I feel close to my partner and ot...  NaN
# 2       fear  Every time I imagine that someone I love or I ...  NaN
# 3      anger  When I had been obviously unjustly treated and...  NaN
# 4    sadness  When I think about the short time that we live...  NaN

# %%
df.tail()
# Out:
#           0                                                  1    2
# 7512  shame  Two years back someone invited me to be the tu...  NaN
# 7513  shame  I had taken the responsibility to do something...  NaN
# 7514   fear  I was at home and I heard a loud sound of spit...  NaN
# 7515  guilt  I did not do the homework that the teacher had...  NaN
# 7516   fear  I had shouted at my younger brother and he was...  NaN

# %%
print(df.columns)
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
# Count the number of sentences per emotion category
emotion_counts = df[0].value_counts()

# Print the emotion categories and their sentence counts
print("Emotion Categories and Number of Sentences:")
print(emotion_counts)
# Out:
# Emotion Categories and Number of Sentences:
# 0
# joy          1092
# sadness      1082
# anger        1079
# fear         1076
# shame        1071
# disgust      1066
# guilt        1049
# sentiment       1
# guit            1
# Name: count, dtype: int64

# %%
col = [0,1]
new_df = df[col]
new_df = new_df[pd.notnull(df[1])]
new_df.columns = ['Emotion','Text']
new_df.head()
# Out:
#      Emotion                                               Text
# 0  sentiment                                            content
# 1        joy  On days when I feel close to my partner and ot...
# 2       fear  Every time I imagine that someone I love or I ...
# 3      anger  When I had been obviously unjustly treated and...
# 4    sadness  When I think about the short time that we live...

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # Keep letters and spaces
    return text  # Do not remove stopwords or pronouns
new_df['processed_text'] = new_df['Text'].apply(preprocess_text)

# %%
'''def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove special characters and numbers
    text = re.sub(r'[^a-z\s]','',text)
    # Tokenize text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    # Join tokens back to string
    return ' '.join(tokens)

new_df['processed_text'] = new_df['Text'].apply(preprocess_text)
# Out:
#   File "<ipython-input-13-6bac1cd49c0a>", line 1
#     '''def preprocess_text(text):
#     ^
# SyntaxError: incomplete input

# %%
print(new_df)
# Out:
#         Emotion                                               Text  \
# 0     sentiment                                            content
# 1           joy  On days when I feel close to my partner and ot...
# 2          fear  Every time I imagine that someone I love or I ...
# 3         anger  When I had been obviously unjustly treated and...
# 4       sadness  When I think about the short time that we live...
# ...         ...                                                ...
# 7512      shame  Two years back someone invited me to be the tu...
# 7513      shame  I had taken the responsibility to do something...
# 7514       fear  I was at home and I heard a loud sound of spit...
# 7515      guilt  I did not do the homework that the teacher had...
# 7516       fear  I had shouted at my younger brother and he was...
#
#                                          processed_text
# 0                                               content
# ...

# %%
new_df.columns
# Out:
# Index(['Emotion', 'Text', 'processed_text'], dtype='object')

# %%
display(new_df)
# Out:
#         Emotion                                               Text  \
# 0     sentiment                                            content
# 1           joy  On days when I feel close to my partner and ot...
# 2          fear  Every time I imagine that someone I love or I ...
# 3         anger  When I had been obviously unjustly treated and...
# 4       sadness  When I think about the short time that we live...
# ...         ...                                                ...
# 7512      shame  Two years back someone invited me to be the tu...
# 7513      shame  I had taken the responsibility to do something...
# 7514       fear  I was at home and I heard a loud sound of spit...
# 7515      guilt  I did not do the homework that the teacher had...
# 7516       fear  I had shouted at my younger brother and he was...
#
#                                          processed_text
# 0                                               content
# ...

# %%
from IPython.display import display
display(new_df[['Text', 'processed_text']].head(10))
# Out:
#                                                 Text  \
# 0                                            content
# 1  On days when I feel close to my partner and ot...
# 2  Every time I imagine that someone I love or I ...
# 3  When I had been obviously unjustly treated and...
# 4  When I think about the short time that we live...
# 5  At a gathering I found myself involuntarily si...
# 6  When I realized that I was directing the feeli...
# 7  I feel guilty when when I realize that I consi...
# 8  After my girlfriend had taken her exam we went...
# 9  When, for the first time I realized the meanin...
#
#                                       processed_text
# 0                                            content
# 1  on days when i feel close to my partner and ot...
# 2  every time i imagine that someone i love or i ...
# 3  when i had been obviously unjustly treated and...
# 4  when i think about the short time that we live...
# 5  at a gathering i found myself involuntarily si...
# ...

# %%
print(new_df.columns)
# Out:
# Index(['Emotion', 'Text', 'processed_text'], dtype='object')

# %%
# !pip install transformers torch numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 89.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 769.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 13.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import torch
from transformers import BertTokenizer, BertModel

# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
import torch
from transformers import BertTokenizer, BertModel

# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased') # Changed 'model' to 'bert_model'

def get_bert_embeddings(text):
    # Tokenize input text and convert to tensor
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)

    # Get BERT embeddings
    with torch.no_grad():
        outputs = bert_model(**inputs) # Use 'bert_model' instead of 'model'

    # Extract the embeddings (CLS token or mean of token embeddings)
    cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze().numpy()  # CLS token embedding
    return cls_embedding

# %%
import numpy as np

# Apply the function to get embeddings for each text entry
new_df['bert_embedding'] = new_df['processed_text'].apply(lambda x: get_bert_embeddings(x))

# Convert embeddings to a NumPy array for easier manipulation
bert_embeddings = np.stack(new_df['bert_embedding'].values)

# %%
new_df[['processed_text', 'bert_embedding']].head()
# Out:
#                                       processed_text  \
# 0                                            content
# 1  on days when i feel close to my partner and ot...
# 2  every time i imagine that someone i love or i ...
# 3  when i had been obviously unjustly treated and...
# 4  when i think about the short time that we live...
#
#                                       bert_embedding
# 0  [-0.15086861, 0.20301004, 0.12541619, -0.28433...
# 1  [0.00352817, 0.14541566, -0.4263868, -0.569416...
# 2  [0.14523004, 0.36880141, 0.050217956, -0.41835...
# 3  [-0.12886731, -0.18776181, -0.36551777, -0.070...
# 4  [-0.047033824, 0.09166263, -0.52117705, -0.571...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Convert embeddings to NumPy array
X = np.stack(new_df['bert_embedding'].values)  # BERT embeddings
y = new_df['Emotion'].values  # Emotion labels (e.g., 'happy', 'sad', etc.)

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_onehot = to_categorical(y_encoded)  # Convert to one-hot encoding

# Split into Train & Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42)

# Normalize embeddings (optional but helps with LSTM performance)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Reshape input for LSTM (LSTM expects 3D input: samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))  # (samples, timesteps=1, features=768)
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %%
from tensorflow.keras.layers import LayerNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
# Define Improved LSTM Model
model = Sequential([
    Bidirectional(LSTM(256, return_sequences=True, input_shape=(1, X_train.shape[2]))),
    LayerNormalization(),
    Dropout(0.3),

    Bidirectional(LSTM(128, return_sequences=True)),
    LayerNormalization(),
    Dropout(0.3),

    Bidirectional(LSTM(64)),  # Final LSTM layer without return_sequences
    Dropout(0.3),

    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(y_train.shape[1], activation='softmax')  # Softmax for multi-class classification
])

# Compile with learning rate decay
optimizer = Adam(learning_rate=0.0001, decay=1e-6)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])


from tensorflow.keras.callbacks import ModelCheckpoint

# Save the best model based on validation accuracy
checkpoint = ModelCheckpoint("best_model.h5", monitor="val_accuracy", save_best_only=True, mode="max")

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/50
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1589 - loss: 2.1638
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.1590 - loss: 2.1636 - val_accuracy: 0.3544 - val_loss: 1.9679
# Epoch 2/50
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report
import numpy as np

# Load the saved best model
best_model = load_model("best_model.h5")
best_model.evaluate(X_test,y_test)

# Generate predictions on the test set using the loaded best model
y_pred = best_model.predict(X_test)  # Get predicted probabilities

# Convert probabilities to class labels
y_pred_labels = np.argmax(y_pred, axis=1)  # Convert predictions to label indices
y_test_labels = np.argmax(y_test, axis=1)  # Convert one-hot encoding to label indices

# Adjust target names dynamically to match unique classes in y_test
unique_classes = np.unique(y_test_labels)  # Find unique labels in y_test
target_names = [label_encoder.classes_[i] for i in unique_classes]  # Ensure correct class names

# Print the classification report
print(classification_report(y_test_labels, y_pred_labels, target_names=target_names))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5700 - loss: 2.0996
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#               precision    recall  f1-score   support
#
#        anger       0.48      0.44      0.46       216
#      disgust       0.57      0.59      0.58       197
#         fear       0.67      0.75      0.71       228
#        guilt       0.47      0.51      0.49       222
#          joy       0.80      0.81      0.80       223
#      sadness       0.63      0.60      0.61       202
#    sentiment       0.00      0.00      0.00         1
#        shame       0.54      0.46      0.49       215
#
#     accuracy                           0.60      1504
#    macro avg       0.52      0.52      0.52      1504
# weighted avg       0.59      0.60      0.59      1504
# ...

# %%
def predict_emotion(text):
    embedding = get_bert_embeddings(text).reshape(1, -1)  # Get BERT embedding
    embedding = scaler.transform(embedding)  # Normalize (same as training data)
    embedding = embedding.reshape((1, 1, embedding.shape[1]))  # Reshape for LSTM
    prediction = model.predict(embedding)
    predicted_label = np.argmax(prediction)  # Get label index
    return label_encoder.inverse_transform([predicted_label])[0]  # Convert index back to label

# Example:
print(predict_emotion("I feel so much happy!"))
print(predict_emotion("I'm happy to loose weight."))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# joy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# joy

# %%
# !pip install gradio

# %%
import gradio as gr
import numpy as np

# Your existing function for emotion prediction

def predict_emotion(text):
    embedding = get_bert_embeddings(text).reshape(1, -1)  # Get BERT embedding
    embedding = scaler.transform(embedding)  # Normalize (same as training data)
    embedding = embedding.reshape((1, 1, embedding.shape[1]))  # Reshape for LSTM
    prediction = model.predict(embedding)
    predicted_label = np.argmax(prediction)  # Get label index
    return label_encoder.inverse_transform([predicted_label])[0]  # Convert index back to label

# Create the Gradio interface
iface = gr.Interface(
    fn=predict_emotion,
    inputs=gr.Textbox(lines=3, placeholder="Enter your text here..."),
    outputs="text",
    title="Emotion Detection",
    description="Enter a sentence and get the predicted emotion.",
    allow_flagging="never"
)

# Launch the UI
iface.launch()
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/interface.py:416: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3bf618d1d9f6a6ce94.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3bf618d1d9f6a6ce94.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
